# %%
import random
j = ["♠","♥","♦","♣"]
i = ["A"]+[str(x) for x in range(2,11)]+["J","Q","K"]
k = [ x + y for x in j for y in i ] + ["JOKER","joker"]
random.shuffle(k)

player1 = []
player2 = []
player3 = []

# while True:
#     y = random.choice(k)
#     if len(k) <= 3:
#         break
#     elif len(player3) < 17:
#         player3.append(y)
#         k.remove(y)
#     elif len(player2) < 17:
#         player2.append(y)
#         k.remove(y)
#     elif len(player1) < 17:
#         player1.append(y)
#         k.remove(y)
        
player1 = k[0:17]
player2 = k[17:34]
player3 = k[34:51]
k = k[51:54]


# for x in range(17):
#     player1.append(random.choice(k))
#     k.remove(player1[x])
#     player2.append(random.choice(k))
#     k.remove(player2[x])
#     player3.append(random.choice(k))
#     k.remove(player3[x])
            
            

print(player1,len(player1))
print(player2,len(player2))
print(player3,len(player3))
print(k)
# Out:
# ['♣4', '♦7', '♣A', '♦J', '♣J', '♦10', '♥9', '♠10', '♥K', '♦Q', '♠6', '♣2', '♦3', '♣10', '♠J', '♠8', '♦2'] 17
# ['♥3', '♥2', '♦4', '♠9', '♣8', '♥A', '♣7', '♠Q', '♦9', '♦A', '♥6', '♥4', '♠3', '♦K', '♠2', '♠K', '♠7'] 17
# ['♥10', '♣6', '♦6', '♥7', '♣5', '♥8', '♠A', 'joker', '♥J', '♦5', '♠5', '♣3', '♣K', '♥Q', '♠4', 'JOKER', '♦8'] 17
# ['♣Q', '♥5', '♣9']

# %%
def iDateCal():
    import time
    TotalDay = (int(time.time())//60//60+8)//24
    InitYear = 1970
    CurYear = 0
    CurYear += InitYear
    for x in range(TotalDay):
        if TotalDay < 365:
            break
        else:
            if CurYear % 4 == 0 and CurYear % 400 != 0:
                CurYear += 1
                TotalDay -= 366
            else:
                CurYear += 1
                TotalDay -= 365
    CurMonth = 1
    CurDay = 0
    CurDay = TotalDay
    for x in range(1,13):
        if (x == 1 or x == 3 or x == 5 or x ==7 or x == 8 or x == 10 or x == 12) and CurDay >=31:
            CurMonth += 1
            CurDay -= 31
        if x ==2 and CurDay >= 29:
            if CurYear % 4 == 0 and CurYear % 400 != 0:
                CurMonth += 1
                CurDay -= 29
            else:
                CurMonth += 1
                CurDay -= 28
        if (x == 4 or x == 6 or x == 9 or x == 11) and CurDay >= 30:
            CurMonth += 1
            CurDay -= 30
    return CurYear,CurMonth,CurDay
            
x,y,z= iDateCal()
print(x,y,z)

# %%
def iDateCal():
    import time
    TotalDay = (int(time.time())//60//60+8)//24
    InitYear = 1970
    CurYear = 0
    CurYear += InitYear
    for x in range(TotalDay):
        if TotalDay < 365:
            break
        else:
            if CurYear % 4 == 0 and CurYear % 400 != 0:
                CurYear += 1
                TotalDay -= 366
            else:
                CurYear += 1
                TotalDay -= 365
    CurMonth = 1
    CurDay = 0
    CurDay = TotalDay
    for x in range(1,13):
        if x in [1,3,5,7,8,10,12] and CurDay>=31:
            CurMonth += 1
            CurDay -= 31
        elif x in [4,6,9,11] and CurDay >=30:
            CurMonth += 1
            CurDay -= 30                   
        elif x == 2 and CurDay >= 29:
            if CurYear % 4 == 0 and CurYear % 400 != 0:
                CurMonth += 1
                CurDay -= 29
            else:
                CurMonth += 1
                CurDay -= 28

    return CurYear,CurMonth,CurDay
            
x,y,z= iDateCal()
print(x,y,z)
