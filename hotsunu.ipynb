# %%
import random
j = ["♠","♥","♦","♣"]
i = ["A"]+[str(x) for x in range(2,11)]+["J","Q","K"]
k = [ x + y for x in j for y in i ] + ["JOKER","joker"]
random.shuffle(k)

player1 = []
player2 = []
player3 = []

# while True:
#     y = random.choice(k)
#     if len(k) <= 3:
#         break
#     elif len(player3) < 17:
#         player3.append(y)
#         k.remove(y)
#     elif len(player2) < 17:
#         player2.append(y)
#         k.remove(y)
#     elif len(player1) < 17:
#         player1.append(y)
#         k.remove(y)
        
player1 = k[0:17]
player2 = k[17:34]
player3 = k[34:51]
k = k[51:54]


# for x in range(17):
#     player1.append(random.choice(k))
#     k.remove(player1[x])
#     player2.append(random.choice(k))
#     k.remove(player2[x])
#     player3.append(random.choice(k))
#     k.remove(player3[x])
            
            

print(player1,len(player1))
print(player2,len(player2))
print(player3,len(player3))
print(k)
# Out:
# ['♥6', '♠4', '♦4', '♦9', 'joker', '♠A', '♥9', '♦8', '♦A', '♣7', '♦2', '♠7', '♠5', '♥8', '♥J', '♣6', '♦6'] 17
# ['♦3', '♦5', '♦K', '♠K', '♦7', '♠6', 'JOKER', '♠10', '♥K', '♥2', '♠Q', '♠J', '♥10', '♥4', '♠2', '♣Q', '♠8'] 17
# ['♣10', '♥5', '♣4', '♣5', '♥A', '♥3', '♣A', '♥Q', '♣3', '♣K', '♣2', '♣9', '♣8', '♠9', '♦J', '♠3', '♥7'] 17
# ['♦10', '♦Q', '♣J']
